# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
VIX_DATA = pd.read_csv('VIX_History.csv', parse_dates=['DATE'], index_col='DATE')
VIX_DATA.drop(columns=['OPEN', 'LOW', 'CLOSE'], inplace=True)

print(VIX_DATA.head())
# Out:
#              HIGH
# DATE
# 1990-01-02  17.24
# 1990-01-03  18.19
# 1990-01-04  19.22
# 1990-01-05  20.11
# 1990-01-08  20.26

# %%
#remove the year from the DATE column: then only organize by month. 
#try to make a dictionary? Where the key is the year (or, year since 1990 includive)
#value of the dictionary is then the range of VIX highs for that month.
